# %% [markdown]
# # Lab 3: Neural Networks: Feedforward Networks and the Training Process
#
# **Duration:** 1 week [21 Jul - 28 Jul, 2026]
# **Due Date:** 28th July, 2026
# **Format:** Jupyter Notebook / Google Colab
# **Grading:** This is a graded lab.
#
# **Student Name:** Gabriel Akurang
# **Student ID:** 35882028
#
# ---
#
# ### Objective
#
# This lab bridges the gap between classical ML and deep learning. Instead of calling
# `.fit()` and trusting scikit-learn, you will **open the black box**: build a neural network
# from a single neuron upward, watch gradient descent learn, and then train a full
# **feedforward network (MLP) in PyTorch** on a dataset you already know from Lab 2.
#
# By the end you should be able to explain, and demonstrate with your own plots, what each
# of these really does: **weights, activation functions, loss, gradients, learning rate,
# epochs, batches, and overfitting**.
#
# We deliberately stay on **tabular data** this week. Images and CNNs come in the next lab.

# %% [markdown]
# ---
# ### Part 0: Repository Setup *(done outside this notebook)*
#
# 1. Create a **public** repository named `lab-3` on GitHub/GitLab.
# 2. Clone it locally (or link it to Google Colab).
# 3. Save this notebook inside the repo as `lab_3.ipynb`.
# 4. Add a `requirements.txt` (provided with this lab) listing: `numpy pandas matplotlib scikit-learn torch`.
# 5. Commit and push after completing **each Part** below — we will check your commit history.
#    A single "final commit" with everything at once loses marks.

# %%
# Standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

# You will import the specific sklearn modules you need inside each section.
# Example: from sklearn.model_selection import train_test_split

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
RANDOM_STATE = 42
torch.manual_seed(RANDOM_STATE)   # use this everywhere so your results are reproducible
np.random.seed(RANDOM_STATE)

print("Running on:", DEVICE)
# Out:
# Running on: cpu

# %% [markdown]
# ---
# # Section 1 — Inside a Neural Network: From One Neuron to Gradient Descent
#
# Before touching PyTorch's automation, you will build the moving parts **yourself with NumPy**
# on a toy problem, so that nothing later in the lab is magic.
#
# The toy problem: learn the function `y = sin(x)` on the interval `[-3, 3]` from 100 noisy
# samples. It is 1-dimensional, so we can *plot everything* — the data, the model's prediction,
# and the loss going down.

# %% [markdown]
# ### Part 1.1 — A single neuron is just a line
# A neuron computes `y_hat = w * x + b`. Fit it to the sine data with **manual gradient descent**.

# %%
# TODO: Generate the toy data
#   x = np.linspace(-3, 3, 100); y = np.sin(x) + small Gaussian noise (std=0.1)
#   Plot it.
torch.manual_seed(RANDOM_STATE)   # use this everywhere so your results are reproducible
np.random.seed(RANDOM_STATE)
fig, ax = plt.subplots(figsize=(10, 6))

x = np.linspace(-3, 3, 100)
std=0.1
noise = np.random.normal(loc=0,scale=std,size=100)
y = np.sin(x) + noise

# ax.scatter(x, y, label='sin(x)', color='red', linewidth=2)
ax.plot(x, y, label='sin(x)', color='blue', linewidth=2)
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_title('Sine Wave')
ax.legend()
ax.grid(True)
plt.show()

# TODO: Initialise w and b to small random values.

w = np.random.rand() * 0.2
b = np.random.rand() * 0.2

# TODO: Implement ONE gradient-descent step by hand, then loop it for ~200 steps:
#   y_hat = w * x + b
#   loss  = np.mean((y_hat - y) ** 2)               # MSE
#   dw    = np.mean(2 * (y_hat - y) * x)            # dLoss/dw  (derive this on paper!)
#   db    = np.mean(2 * (y_hat - y))                # dLoss/db
#   w    -= lr * dw
#   b    -= lr * db
#   Record the loss at every step.

lr = 0.1
epochs =200

loss_list =[]

for i in range(epochs):
    y_hat = w * x + b
    loss  = np.mean((y_hat - y) ** 2)               
    dw    = np.mean(2 * (y_hat - y) * x)            
    db    = np.mean(2 * (y_hat - y))                
    w    -= lr * dw
    b    -= lr * db
    loss_list.append(loss)



# TODO: Plot (a) the loss curve over the 200 steps, and
#             (b) the data with the fitted line on top.

#a

plt.plot(loss_list)
plt.title("Loss curve")
plt.xlabel("Steps")
plt.ylabel("Loss values")
plt.show()

#b
fig, a = plt.subplots(figsize=(10, 6))

a.plot(x, y, label='sin(x)', color='red', linewidth=2)
a.plot(x, y_hat, color='blue', linewidth=2)
a.set_xlabel('X-axis')
a.set_ylabel('Y-axis')
a.set_title('Sine Wave')
a.legend()
a.grid(True)
plt.show()

# %% [markdown]
# **Student Reasoning — The single neuron**
# *1. Derive `dLoss/dw` on paper and include a photo or the LaTeX in this cell — does it match
# the code?*
# *2. The loss stops improving but the fit is clearly bad. Is this underfitting or overfitting,
# and WHY can a single neuron never fit a sine wave, no matter how long you train?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 1.2 — Hidden layers and activations: why depth helps
# Now build a tiny network **by hand**: 1 input -> a hidden layer of 8 neurons with `tanh` ->
# 1 output. Still NumPy, still manual gradients.

# %%
# TODO: Initialise parameters
#   W1: shape (1, 8),  b1: shape (8,)
#   W2: shape (8, 1),  b2: shape (1,)
#   Small random values (e.g. np.random.randn(...) * 0.5)
torch.manual_seed(RANDOM_STATE)   # use this everywhere so your results are reproducible
np.random.seed(RANDOM_STATE)
W2 = np.random.randn(8,1) * 0.5
W1 = np.random.randn(1,8) * 0.5
b1 = np.random.randn(8) * 0.5
b2 = np.random.randn(1) * 0.5

# TODO: Forward pass (keep the intermediate values — you need them for backprop):
#   z1 = x @ W1 + b1        # pre-activation, shape (100, 8)
#   h  = np.tanh(z1)        # activation
#   y_hat = h @ W2 + b2     # output, shape (100, 1)
#   loss  = np.mean((y_hat - y) ** 2)

x1 = x.reshape(100,1)
y1 = y.reshape(100,1)

z1 = x1 @ W1 + b1        # pre-activation, shape (100, 8)
h  = np.tanh(z1)        # activation
# h = z1
y_hat = h @ W2 + b2     # output, shape (100, 1)
loss  = np.mean((y_hat - y1) ** 2)

# TODO: Backward pass (the chain rule, layer by layer):
#   d_yhat = 2 * (y_hat - y) / len(y)
#   dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
#   dh  = d_yhat @ W2.T
#   dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
#   dW1 = x.T @ dz1 ;  db1 = dz1.sum(axis=0)

d_yhat = 2 * (y_hat - y1) / len(y1)
dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
dh  = d_yhat @ W2.T
dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
dW1 = x1.T @ dz1 ;  db1 = dz1.sum(axis=0)



# TODO: Update all parameters with learning rate lr, loop for ~3000 steps,
#   record the loss.

lr = 0.1
epochs = 3000
list_loss = []

for i in range(epochs):
    z1 = x1 @ W1 + b1        # pre-activation, shape (100, 8)
    h  = np.tanh(z1)        # activation
    # h=z1
    y_hat = h @ W2 + b2     # output, shape (100, 1)
    loss  = np.mean((y_hat - y1) ** 2)

    list_loss.append(loss)

    d_yhat = 2 * (y_hat - y1) / len(y1)
    dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
    dh  = d_yhat @ W2.T
    dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
    dW1 = x1.T @ dz1 ;  db1 = dz1.sum(axis=0)

    
    W1 -= lr * dW1
    W2 -= lr * dW2
    b1 -= lr * db1
    b2 -= lr * db2

# TODO: Plot the loss curve AND the final fit over the data.
#   Then re-run with the tanh REMOVED (h = z1). What happens to the fit?

plt.plot(list_loss)
plt.title("Loss curve")
plt.xlabel("Steps")
plt.ylabel("Loss values")
plt.show()

plt.plot(x, y)
plt.plot(x,y_hat)
plt.show()

#Without tanh

W2 = np.random.randn(8,1) * 0.5
W1 = np.random.randn(1,8) * 0.5
b1 = np.random.randn(8) * 0.5
b2 = np.random.randn(1) * 0.5

z1 = x1 @ W1 + b1        # pre-activation, shape (100, 8)
h  = np.tanh(z1)        # activation
# h = z1
y_hat = h @ W2 + b2     # output, shape (100, 1)
loss  = np.mean((y_hat - y1) ** 2)

# TODO: Backward pass (the chain rule, layer by layer):
#   d_yhat = 2 * (y_hat - y) / len(y)
#   dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
#   dh  = d_yhat @ W2.T
#   dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
#   dW1 = x.T @ dz1 ;  db1 = dz1.sum(axis=0)

d_yhat = 2 * (y_hat - y1) / len(y1)
dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
dh  = d_yhat @ W2.T
dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
dW1 = x1.T @ dz1 ;  db1 = dz1.sum(axis=0)



# TODO: Update all parameters with learning rate lr, loop for ~3000 steps,
#   record the loss.

lr = 0.1
epochs = 3000
list_loss = []

for i in range(epochs):
    z1 = x1 @ W1 + b1        # pre-activation, shape (100, 8)
    h =z1
    y_hat = h @ W2 + b2     # output, shape (100, 1)
    loss  = np.mean((y_hat - y1) ** 2)

    list_loss.append(loss)

    d_yhat = 2 * (y_hat - y1) / len(y1)
    dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
    dh  = d_yhat @ W2.T
    dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
    dW1 = x1.T @ dz1 ;  db1 = dz1.sum(axis=0)

    
    W1 -= lr * dW1
    W2 -= lr * dW2
    b1 -= lr * db1
    b2 -= lr * db2



plt.plot(x, y)
plt.plot(x,y_hat)
plt.title(" Final fit Without tanh")
plt.show()

# %% [markdown]
# **Student Reasoning — Depth and activations**
# *1. With tanh removed, the deep network fits no better than the single neuron of Part 1.1.
# Explain mathematically why a stack of linear layers collapses into one linear layer.*
# *2. What role did the hidden layer's 8 neurons play in fitting the curve? (Hint: plot a few
# columns of `h` against `x`.)*
# *3. This is exactly what `loss.backward()` will automate in Section 2. In one sentence, what
# is backpropagation?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 1.3 — The learning rate: too cold, too hot, just right
# The single most important hyperparameter. See its three regimes with your own eyes.

# %%
# TODO: Wrap your Part 1.2 training loop in a function train_toy(lr, steps=3000)
#   that returns the list of losses.

def train_toy(lr, steps=3000): 

    torch.manual_seed(RANDOM_STATE)   # use this everywhere so your results are reproducible
    np.random.seed(RANDOM_STATE)

    W2 = np.random.randn(8,1) * 0.5
    W1 = np.random.randn(1,8) * 0.5
    b1 = np.random.randn(8) * 0.5
    b2 = np.random.randn(1) * 0.5
    
    list_loss = []

    for i in range(steps):
        z1 = x1 @ W1 + b1        # pre-activation, shape (100, 8)
        h  = np.tanh(z1)        # activation
        # h=z1
        y_hat = h @ W2 + b2     # output, shape (100, 1)
        loss  = np.mean((y_hat - y1) ** 2)

        list_loss.append(loss)

        d_yhat = 2 * (y_hat - y1) / len(y1)
        dW2 = h.T @ d_yhat ;  db2 = d_yhat.sum(axis=0)
        dh  = d_yhat @ W2.T
        dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh
        dW1 = x1.T @ dz1 ;  db1 = dz1.sum(axis=0)

        
        W1 -= lr * dW1
        W2 -= lr * dW2
        b1 -= lr * db1
        b2 -= lr * db2

    return list_loss

# TODO: Run it with THREE learning rates, e.g. lr = 0.001, 0.05, 1.0
#   (keep the same initial weights for a fair comparison — reset the seed).

a1 = train_toy(0.001, steps=3000)
a2 = train_toy(0.05, steps=3000)
a3 = train_toy(1, steps=3000)


# TODO: Plot the three loss curves on the same axes (log scale on y helps), with a legend.

plt.plot(range(3000),np.log(a1),label='LR = 0.001')
plt.plot(range(3000),np.log(a2),label='LR = 0.05')
plt.plot(range(3000), np.log(a3),label='LR = 1.0')
plt.ylim(-5,25)
plt.plot()

plt.legend()
plt.show()
# Out:
# /Users/Takyi/Desktop/ISEHSA/year2sem2/AI/ai_labs/lab-3/ai_env/lib/python3.12/site-packages/numpy/_core/_methods.py:132: RuntimeWarning: overflow encountered in reduce
#   ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
# /var/folders/1z/5rdr8dkx1496nb1jqzwpy0pr0000gp/T/ipykernel_7749/229790272.py:21: RuntimeWarning: overflow encountered in square
#   loss  = np.mean((y_hat - y1) ** 2)
# /var/folders/1z/5rdr8dkx1496nb1jqzwpy0pr0000gp/T/ipykernel_7749/229790272.py:27: RuntimeWarning: overflow encountered in matmul
#   dh  = d_yhat @ W2.T
# /var/folders/1z/5rdr8dkx1496nb1jqzwpy0pr0000gp/T/ipykernel_7749/229790272.py:28: RuntimeWarning: invalid value encountered in multiply
#   dz1 = dh * (1 - np.tanh(z1) ** 2)     # derivative of tanh

# %% [markdown]
# **Student Reasoning — Learning rate**
# *Describe what each of the three curves shows. Why does a too-large learning rate make the
# loss explode or oscillate instead of just "learning faster"?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ---
# # Section 2 — A Real Feedforward Network in PyTorch
#
# Now we let PyTorch do the bookkeeping (`autograd`, optimizers, batching) and apply the ideas
# from Section 1 to a real problem — one you already know:
#
# ## Predicting obesity level (`NObeyesdad`) — the Lab 2 dataset
#
# Same data, same 7 classes, same preprocessing ideas — but this time the model is a neural
# network you design and train yourself. At the end you will compare it head-to-head with your
# Lab 2 classical models.

# %% [markdown]
# ### Part 2.1 — Preprocess and split (recycled from Lab 2)
# Reuse your Lab 2 pipeline: encode categoricals, scale numerics, stratified three-way split.

# %%
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# TODO: Load the obesity dataset (same OBESITY_URL as Lab 2).

OBESITY_URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/GkDzb7bWrtvGXdPOfk6CIg/Obesity-level-prediction-dataset.csv"
obesity = pd.read_csv(OBESITY_URL)

# TODO: Encode categoricals exactly as you did in Lab 2
#   (binary yes/no -> 0/1; Gender/MTRANS/CAEC/CALC -> your justified choice).
#   Encode the target NObeyesdad into integers 0..6 (LabelEncoder) — CrossEntropyLoss
#   expects integer class indices.

binary_cols = ['family_history_with_overweight', 'FAVC', 'SMOKE', 'SCC']

for col in binary_cols:
    obesity[col] = obesity[col].map({'yes': 1, 'no': 0})

caec_mapping = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}
calc_mapping = {'no': 0, 'Sometimes': 1, 'Frequently': 2, 'Always': 3}


obesity['CAEC'] = obesity['CAEC'].map(caec_mapping)
obesity['CALC'] = obesity['CALC'].map(calc_mapping)

obesity = pd.get_dummies(obesity, columns=['Gender', 'MTRANS'], drop_first=True)

encoder = LabelEncoder()
obesity['NObeyesdad'] = encoder.fit_transform(obesity['NObeyesdad'])

# TODO: Stratified train / validation / test split (60/20/20, stratify=y,
#   random_state=RANDOM_STATE).

X = obesity.drop(columns=['NObeyesdad'])
y = obesity['NObeyesdad']


X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.20, random_state=RANDOM_STATE, stratify=y)

X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, random_state=RANDOM_STATE, stratify=y_temp)


# TODO: Fit a StandardScaler on the TRAINING set only; transform all three splits.
#   (Neural networks are far more sensitive to feature scale than random forests — 
#    remember Section 1, where all gradients depended on x!)

numeric_cols = ['Age', 'Height', 'Weight', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE']

X_train_scaled = X_train.copy()
X_val_scaled = X_val.copy()
X_test_scaled = X_test.copy()

scaler = StandardScaler()

X_train_scaled[numeric_cols] = scaler.fit_transform(X_train[numeric_cols])

X_val_scaled[numeric_cols] = scaler.transform(X_val[numeric_cols])
X_test_scaled[numeric_cols] = scaler.transform(X_test[numeric_cols])

# TODO: Convert to tensors and wrap in DataLoaders:
#   X -> torch.float32, y -> torch.long
#   train_loader (batch_size=32, shuffle=True), val_loader, test_loader


X_train_tensor = torch.tensor(X_train_scaled.to_numpy(), dtype=torch.float32)
X_val_tensor   = torch.tensor(X_val_scaled.to_numpy(),   dtype=torch.float32)
X_test_tensor  = torch.tensor(X_test_scaled.to_numpy(),  dtype=torch.float32)

y_train_tensor = torch.tensor(y_train.to_numpy(), dtype=torch.long)
y_val_tensor   = torch.tensor(y_val.to_numpy(),   dtype=torch.long)
y_test_tensor  = torch.tensor(y_test.to_numpy(),  dtype=torch.long)

train_loader = DataLoader( TensorDataset(X_train_tensor,y_train_tensor),
                          batch_size=32,
                          shuffle=True,
                          )

val_loader = DataLoader( TensorDataset(X_val_tensor,y_val_tensor),
                          batch_size=32,
                          shuffle=True,
                          )

test_loader = DataLoader( TensorDataset(X_test_tensor,y_test_tensor),
                          batch_size=32,
                          shuffle=True,
                          )

# %% [markdown]
# **Student Reasoning — Preprocessing for neural networks**
# *1. Why does CrossEntropyLoss need integer class labels rather than one-hot vectors in
# PyTorch?*
# *2. A random forest in Lab 2 did not care about feature scaling. Why do neural networks care
# so much? Connect your answer to the gradient formulas you wrote in Section 1.*
# *3. What does `shuffle=True` on the training DataLoader do, and why does it help?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 2.2 — Design the network
# An MLP: input -> hidden layers with ReLU -> 7 output logits.

# %%
import torch.nn.functional as F

# TODO: Define a FeedForwardNet class (subclass nn.Module) with:
#   - constructor args: input_dim, hidden_sizes=(64, 32), n_classes=7
#   - at least TWO hidden layers with ReLU activations
#   - output layer producing 7 raw logits
#     (NO softmax — nn.CrossEntropyLoss applies log-softmax internally)

# class FeedForwardNet(nn.Module):
#     def __init__(self, ...):
#         ...
#     def forward(self, x):
#         ...

class FeedForwardNet(nn.Module):
    def __init__(self,input_dim=7, hidden_sizes=(64, 32), n_classes=7):
        super().__init__()

        self.fc1 = nn.Linear(input_dim, hidden_sizes[0])
        self.fc2 = nn.Linear(hidden_sizes[0],hidden_sizes[1])
        self.output = nn.Linear(hidden_sizes[1],n_classes)

        

    def forward(self, x):

        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x= self.output(x)

        return x

class FeedForwardNetUpdate(nn.Module):
    def __init__(self, input_dim, hidden_sizes=(64, 32), n_classes=7, dropout=0.0):
        super().__init__()

        self.hidden_sizes = hidden_sizes
        self.layers = nn.ModuleDict()
        self.dropout = nn.Dropout(dropout)
        self.in_dim=input_dim

        for i in range(len(hidden_sizes)):
            self.layers[f"fc{i+1}"]=nn.Linear(self.in_dim, hidden_sizes[i])
            self.in_dim=hidden_sizes[i]
        
        self.output=nn.Linear(self.in_dim, n_classes)


    def forward(self, x):
        for i in range(len(self.hidden_sizes)):
            x = F.relu(self.layers[f"fc{i + 1}"](x))
            x = self.dropout(x)

        x = self.output(x)

        return x

# TODO: Instantiate, move to DEVICE, print the model.

model = FeedForwardNet(X_train_scaled.shape[1]).to(DEVICE)
print(model)

# TODO: Count trainable parameters:
#   sum(p.numel() for p in model.parameters() if p.requires_grad)
#   Verify the count for the FIRST layer by hand: input_dim * 64 + 64.

trainable_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)
print(f"Trainable parameters: {trainable_parameters}")
# Out:
# FeedForwardNet(
#   (fc1): Linear(in_features=19, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (output): Linear(in_features=32, out_features=7, bias=True)
# )
# Trainable parameters: 3591

# %% [markdown]
# **Student Reasoning — Architecture**
# *1. Show the by-hand parameter count for every layer and confirm it matches PyTorch.*
# *2. Why ReLU here instead of the tanh you used in Section 1? Name one advantage.*
# *3. What would the network compute if you removed the ReLUs? (You proved this in Part 1.2.)*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 2.3 — The training loop
# The same loop you built by hand in Section 1 — now with autograd, an optimizer, and batches.

# %%
import time
# TODO: criterion = nn.CrossEntropyLoss()
#       optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)   # or SGD — justify

criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# TODO: Train for at least 50 epochs. Each epoch:
#   1. model.train(); for xb, yb in train_loader:
#        optimizer.zero_grad()
#        logits = model(xb.to(DEVICE))
#        loss = criterion(logits, yb.to(DEVICE))
#        loss.backward()          # <- the backprop you wrote by hand in Part 1.2
#        optimizer.step()         # <- the update rule you wrote in Part 1.1
#   2. model.eval() + torch.no_grad(): compute loss AND accuracy on train and validation sets
#   3. Append everything to history lists; print a one-line summary per epoch.

epochs = 50
best_val_acc = 0
start_time = time.time()

history = { "train_loss": [],  "val_loss": [], "train_acc": [], "val_acc": [] }

for i in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for xb, yb in train_loader:

        xb = xb.to(DEVICE)
        yb = yb.to(DEVICE)

        optimizer.zero_grad()

        logits = model(xb)
        loss = criterion(logits, yb)

        loss.backward()
        optimizer.step()

        running_loss += loss.item() * xb.size(0)

        predictions = logits.argmax(dim=1)
        correct += (predictions == yb).sum().item()
        total += yb.size(0)

    train_loss = running_loss / total
    train_acc = correct / total

    history["train_loss"].append(train_loss)
    history["train_acc"].append(train_acc)


    model.eval()

    with torch.no_grad():

        running_val_loss = 0.0
        val_correct = 0
        val_total = 0

        for xb, yb in val_loader:

            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)

            logits = model(xb)
            loss = criterion(logits, yb)

            running_val_loss += loss.item() * xb.size(0)

            predictions = logits.argmax(dim=1)
            val_correct += (predictions == yb).sum().item()
            val_total += yb.size(0)

    val_loss = running_val_loss / val_total
    val_acc = val_correct / val_total

    history["val_acc"].append(val_acc)
    history["val_loss"].append(val_loss)

    print(f'Epoch No: {i + 1}, Training Accuracy: {train_acc}, Training Loss: {train_loss}, Validation Accuracy: {val_acc}, Validation Loss: {val_loss}')

# TODO: Save the best model (highest validation accuracy):
#   torch.save(model.state_dict(), "ffn_best.pt")

    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), "ffn_best.pt")

end_time = time.time()

training_time = end_time - start_time 


# TODO: Plot loss curves (train + val) and accuracy curves (train + val), with legends.

# Loss curve
plt.figure(figsize=(8,5))
plt.plot(range(epochs), history["train_loss"], label="Train Loss")
plt.plot(range(epochs), history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid(True)
plt.show()

# Accuracy curve
plt.figure(figsize=(8,5))
plt.plot(range(epochs), history["train_acc"], label="Train Accuracy")
plt.plot(range(epochs), history["val_acc"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch No: 1, Training Accuracy: 0.22037914691943128, Training Loss: 1.9062868392486332, Validation Accuracy: 0.3246445497630332, Validation Loss: 1.84390133817049
# Epoch No: 2, Training Accuracy: 0.4067930489731438, Training Loss: 1.7480872820527256, Validation Accuracy: 0.495260663507109, Validation Loss: 1.5982134443888731
# Epoch No: 3, Training Accuracy: 0.5505529225908373, Training Loss: 1.4032707161624662, Validation Accuracy: 0.6137440758293838, Validation Loss: 1.1943087911153856
# Epoch No: 4, Training Accuracy: 0.6042654028436019, Training Loss: 1.0681524756960394, Validation Accuracy: 0.6872037914691943, Validation Loss: 0.9237008945071866
# Epoch No: 5, Training Accuracy: 0.6951026856240127, Training Loss: 0.8438565555906974, Validation Accuracy: 0.7251184834123223, Validation Loss: 0.7672685472321171
# Epoch No: 6, Training Accuracy: 0.7543443917851501, Training Loss: 0.6956432295071571, Validation Accuracy: 0.7914691943127962, Validation Loss: 0.642987165405852
# Epoch No: 7, Training Accuracy: 0.8206951026856241, Training Loss: 0.5822894156073318, Validation Accuracy: 0.8127962085308057, Validation Loss: 0.5553008775575466
# Epoch No: 8, Training Accuracy: 0.8436018957345972, Training Loss: 0.5018481656461719, Validation Accuracy: 0.8127962085308057, Validation Loss: 0.5088931343284263
# Epoch No: 9, Training Accuracy: 0.868088467614534, Training Loss: 0.43835438310064223, Validation Accuracy: 0.8578199052132701, Validation Loss: 0.43336766139025934
# Epoch No: 10, Training Accuracy: 0.8981042654028436, Training Loss: 0.3831894926456102, Validation Accuracy: 0.8744075829383886, Validation Loss: 0.3922930515207951
# Epoch No: 11, Training Accuracy: 0.9091627172195893, Training Loss: 0.33879896974864915, Validation Accuracy: 0.8791469194312796, Validation Loss: 0.3592333635447715
# Epoch No: 12, Training Accuracy: 0.9186413902053713, Training Loss: 0.30613496042729177, Validation Accuracy: 0.9028436018957346, Validation Loss: 0.32296028874496713
# Epoch No: 13, Training Accuracy: 0.9257503949447078, Training Loss: 0.27642743910940903, Validation Accuracy: 0.9052132701421801, Validation Loss: 0.30829986442604335
# Epoch No: 14, Training Accuracy: 0.9447077409162717, Training Loss: 0.2520749986548371, Validation Accuracy: 0.9170616113744076, Validation Loss: 0.2831713887752515
# Epoch No: 15, Training Accuracy: 0.9423380726698263, Training Loss: 0.23033523220586552, Validation Accuracy: 0.9170616113744076, Validation Loss: 0.26951052862886005
# Epoch No: 16, Training Accuracy: 0.9502369668246445, Training Loss: 0.21651313400946523, Validation Accuracy: 0.9052132701421801, Validation Loss: 0.26898244983777053
# Epoch No: 17, Training Accuracy: 0.9478672985781991, Training Loss: 0.20229073711575302, Validation Accuracy: 0.9241706161137441, Validation Loss: 0.24464030719198887
# Epoch No: 18, Training Accuracy: 0.9518167456556083, Training Loss: 0.1860083331005268, Validation Accuracy: 0.933649289099526, Validation Loss: 0.2265841901584824
# Epoch No: 19, Training Accuracy: 0.9589257503949447, Training Loss: 0.17113849508913018, Validation Accuracy: 0.933649289099526, Validation Loss: 0.22115986176294172
# Epoch No: 20, Training Accuracy: 0.9620853080568721, Training Loss: 0.16270816771057545, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.2200111656392355
# Epoch No: 21, Training Accuracy: 0.9581358609794629, Training Loss: 0.15272166291590175, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.2163408627442274
# Epoch No: 22, Training Accuracy: 0.9676145339652449, Training Loss: 0.14212835731947027, Validation Accuracy: 0.933649289099526, Validation Loss: 0.20485429243312628
# Epoch No: 23, Training Accuracy: 0.9699842022116903, Training Loss: 0.1358030562246392, Validation Accuracy: 0.933649289099526, Validation Loss: 0.19345299896047013
# Epoch No: 24, Training Accuracy: 0.9660347551342812, Training Loss: 0.12908540444822297, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.20231044433693185
# Epoch No: 25, Training Accuracy: 0.9715639810426541, Training Loss: 0.1218967827634318, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.19258245555639833
# Epoch No: 26, Training Accuracy: 0.9770932069510269, Training Loss: 0.11476604441566302, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.20189981784018296
# Epoch No: 27, Training Accuracy: 0.9699842022116903, Training Loss: 0.11392373977726293, Validation Accuracy: 0.933649289099526, Validation Loss: 0.1805804748953236
# Epoch No: 28, Training Accuracy: 0.9723538704581358, Training Loss: 0.10742701156326756, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.18456881749333365
# Epoch No: 29, Training Accuracy: 0.9794628751974723, Training Loss: 0.10063360709149691, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.17693025848311836
# Epoch No: 30, Training Accuracy: 0.9786729857819905, Training Loss: 0.09811336717805215, Validation Accuracy: 0.933649289099526, Validation Loss: 0.18325446920372299
# Epoch No: 31, Training Accuracy: 0.9778830963665087, Training Loss: 0.09351064973344547, Validation Accuracy: 0.9289099526066351, Validation Loss: 0.18520585465205225
# Epoch No: 32, Training Accuracy: 0.9794628751974723, Training Loss: 0.08974103344748559, Validation Accuracy: 0.9407582938388626, Validation Loss: 0.16513138783486533
# Epoch No: 33, Training Accuracy: 0.9786729857819905, Training Loss: 0.08229939858495341, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.17504904625310574
# Epoch No: 34, Training Accuracy: 0.9755134281200631, Training Loss: 0.08261971402248312, Validation Accuracy: 0.943127962085308, Validation Loss: 0.16397598896052035
# Epoch No: 35, Training Accuracy: 0.9818325434439179, Training Loss: 0.0757173798731153, Validation Accuracy: 0.9383886255924171, Validation Loss: 0.17225399920584467
# Epoch No: 36, Training Accuracy: 0.9849921011058452, Training Loss: 0.07541311044381316, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.15713955811555916
# Epoch No: 37, Training Accuracy: 0.9873617693522907, Training Loss: 0.06919168942206279, Validation Accuracy: 0.9312796208530806, Validation Loss: 0.1553790953707709
# Epoch No: 38, Training Accuracy: 0.9849921011058452, Training Loss: 0.06831785294964415, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.15797256456767494
# Epoch No: 39, Training Accuracy: 0.985781990521327, Training Loss: 0.06642058411669015, Validation Accuracy: 0.9383886255924171, Validation Loss: 0.1520914884540142
# Epoch No: 40, Training Accuracy: 0.9897314375987362, Training Loss: 0.06213477310411173, Validation Accuracy: 0.9383886255924171, Validation Loss: 0.15571246296167374
# Epoch No: 41, Training Accuracy: 0.9889415481832543, Training Loss: 0.0589949352222408, Validation Accuracy: 0.9312796208530806, Validation Loss: 0.15642686272966919
# Epoch No: 42, Training Accuracy: 0.9889415481832543, Training Loss: 0.05987710405088149, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.1507518353101784
# Epoch No: 43, Training Accuracy: 0.990521327014218, Training Loss: 0.054579130593116434, Validation Accuracy: 0.943127962085308, Validation Loss: 0.15702435123553207
# Epoch No: 44, Training Accuracy: 0.990521327014218, Training Loss: 0.054569763359488654, Validation Accuracy: 0.9312796208530806, Validation Loss: 0.16792817776184088
# Epoch No: 45, Training Accuracy: 0.9897314375987362, Training Loss: 0.05328680740266238, Validation Accuracy: 0.933649289099526, Validation Loss: 0.15008804087319647
# Epoch No: 46, Training Accuracy: 0.9897314375987362, Training Loss: 0.05042650022118766, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.1611598132451846
# Epoch No: 47, Training Accuracy: 0.9889415481832543, Training Loss: 0.05141647491827725, Validation Accuracy: 0.9360189573459715, Validation Loss: 0.16860186704103416
# Epoch No: 48, Training Accuracy: 0.990521327014218, Training Loss: 0.047798798241509836, Validation Accuracy: 0.9383886255924171, Validation Loss: 0.1473947087064456
# Epoch No: 49, Training Accuracy: 0.990521327014218, Training Loss: 0.043737822387361604, Validation Accuracy: 0.9407582938388626, Validation Loss: 0.15693268095147553
# Epoch No: 50, Training Accuracy: 0.990521327014218, Training Loss: 0.04560244209640681, Validation Accuracy: 0.933649289099526, Validation Loss: 0.15270054354486873

# %% [markdown]
# **Student Reasoning — Training**
# *1. Map each line of the PyTorch loop to the NumPy code you wrote in Section 1: which line is
# the forward pass, which computes gradients, which is the update rule?*
# *2. Looking at your curves, is the model overfitting, underfitting, or well-fitted? Quote the
# specific numbers that back up your claim.*
# *3. Why do we call `optimizer.zero_grad()` every batch? What silently goes wrong without it?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 2.4 — Experiments: how training choices change the outcome
# Run **three controlled experiments**. Change ONE thing at a time; keep everything else fixed.

# %%
# Wrap your Part 2.3 loop in a function first:
#   def run_experiment(hidden_sizes=(64, 32), lr=1e-3, batch_size=32, epochs=50, dropout=0.0):
#       ... returns history dict ...

def run_experiment(hidden_sizes=(64, 32), lr=1e-3, batch_size=32, epochs=50, dropout=0.0):

    train_loader = DataLoader( TensorDataset(X_train_tensor,y_train_tensor),
                          batch_size=32,
                          shuffle=True,
                          )

    val_loader = DataLoader( TensorDataset(X_val_tensor,y_val_tensor),
                          batch_size=32,
                          shuffle=True,
                          )


    torch.manual_seed(RANDOM_STATE)

    model = FeedForwardNetUpdate(X_train_scaled.shape[1],hidden_sizes=hidden_sizes, dropout=dropout).to(DEVICE)

    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    
    history = { "train_loss": [],  "val_loss": [], "train_acc": [], "val_acc": [] }

    for i in range(epochs):
        model.train()
        running_loss = 0.0
        correct = 0
        total = 0

        for xb, yb in train_loader:

            xb = xb.to(DEVICE)
            yb = yb.to(DEVICE)

            optimizer.zero_grad()

            logits = model(xb)
            loss = criterion(logits, yb)

            loss.backward()
            optimizer.step()

            running_loss += loss.item() * xb.size(0)

            predictions = logits.argmax(dim=1)
            correct += (predictions == yb).sum().item()
            total += yb.size(0)

        train_loss = running_loss / total
        train_acc = correct / total

        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)


        model.eval()

        with torch.no_grad():

            running_val_loss = 0.0
            val_correct = 0
            val_total = 0

            for xb, yb in val_loader:

                xb = xb.to(DEVICE)
                yb = yb.to(DEVICE)

                logits = model(xb)
                loss = criterion(logits, yb)

                running_val_loss += loss.item() * xb.size(0)

                predictions = logits.argmax(dim=1)
                val_correct += (predictions == yb).sum().item()
                val_total += yb.size(0)

        val_loss = running_val_loss / val_total
        val_acc = val_correct / val_total

        history["val_acc"].append(val_acc)
        history["val_loss"].append(val_loss)

    return history 
    

# TODO — Experiment A (capacity): tiny (8,) vs default (64, 32) vs large (256, 128, 64).
#   Plot the three validation-accuracy curves together.

tiny = run_experiment(hidden_sizes=(8,))
default = run_experiment(hidden_sizes=(64,32))
large = run_experiment(hidden_sizes=(256,128,64))

plt.figure(figsize=(8,5))

plt.plot(range(epochs),tiny["val_acc"], label="Tiny (8)")
plt.plot(range(epochs),default["val_acc"], label="Default (64,32)")
plt.plot(range(epochs),large["val_acc"], label="Large (256,128,64)")

plt.xlabel("Epoch")
plt.ylabel("Validation Accuracy")
plt.title("Experiment A: Network Capacity")
plt.legend()
plt.grid(True)
plt.show()


# TODO — Experiment B (learning rate): lr = 1e-4, 1e-3, 1e-1 (same architecture).
#   Plot the three validation-loss curves together. Compare with Part 1.3.

lr_small = run_experiment(lr=1e-4)
lr_default = run_experiment(lr=1e-3)
lr_large = run_experiment(lr=1e-1)

plt.figure(figsize=(8,5))

plt.plot(range(epochs),lr_small["val_loss"], label="LR = 1e-4")
plt.plot(range(epochs),lr_default["val_loss"], label="LR = 1e-3")
plt.plot(range(epochs),lr_large["val_loss"], label="LR = 1e-1")

plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.title("Experiment B: Learning Rate")
plt.legend()
plt.grid(True)
plt.show()

# TODO — Experiment C (regularization): take your LARGEST network and train it
#   with and without nn.Dropout(0.3) after each hidden layer.
#   Plot train vs validation accuracy for both runs.

large_no_dropout = run_experiment(
    hidden_sizes=(256,128,64),
    dropout=0.0
)

large_dropout = run_experiment(
    hidden_sizes=(256,128,64),
    dropout=0.3
)

plt.figure(figsize=(8,5))

plt.plot(range(epochs),large_no_dropout["train_acc"], label="Train (No Dropout)")
plt.plot(range(epochs),large_no_dropout["val_acc"], label="Val (No Dropout)")

plt.plot(range(epochs),large_dropout["train_acc"], label="Train (Dropout)")
plt.plot(range(epochs),large_dropout["val_acc"], label="Val (Dropout)")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Experiment C: Effect of Dropout")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# **Student Reasoning — Experiments**
# *1. Capacity: did the largest network win on validation data? Where do you see diminishing
# returns or overfitting?*
# *2. Learning rate: do the three regimes match what you saw on the toy problem in Part 1.3?*
# *3. Regularization: what did dropout do to the train-vs-validation gap? Explain in one or two
# sentences HOW dropout achieves this.*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ### Part 2.5 — Final evaluation and showdown with Lab 2
# One honest number on the test set — then compare with your classical models.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay

# TODO: Load your best configuration's weights; model.eval().
model= FeedForwardNet(X_train_scaled.shape[1]) 
model.load_state_dict(torch.load("ffn_best.pt"))
model.eval()

# TODO: Report test ACCURACY and MACRO-F1
#   from sklearn.metrics import accuracy_score, f1_score, classification_report

with torch.no_grad():
      y_predictions = []
      y_targets = []
      for xb, yb in test_loader:
        xb = xb.to(DEVICE)
        logits = model(xb)
        loss = criterion(logits, yb)
        preds = logits.argmax(dim=1)

        y_predictions.extend(preds.cpu().tolist())
        y_targets.extend(yb.cpu().tolist())

test_acc = accuracy_score(y_targets, y_predictions)
test_f1 = f1_score(y_targets, y_predictions, average='macro')

print(f"Accuracy Score: {round(test_acc, 3)}, F1 Score: {round(test_f1, 3)}")

# TODO: Confusion matrix for the test set with the 7 class names
#   from sklearn.metrics import ConfusionMatrixDisplay

ConfusionMatrixDisplay.from_predictions(
    y_targets,
    y_predictions,
    xticks_rotation=45,
    display_labels=['Obesity_Type_I','Obesity_Type_II', 'Obesity_Type_III','Overweight_Level_I','Overweight_Level_II','Normal_Weight','Insufficient_Weight' ],
    cmap='Greens')


plt.title("Confusion Matrix ")
plt.show()

# TODO: Build a small comparison table (a pandas DataFrame is fine):
#   rows = [your best Lab 2 classifier, this neural network]
#   cols = [test accuracy, test macro-F1, training time, number of parameters/trees]



nn_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

comparison = pd.DataFrame({
    "Model": [
        "Random Forest Classifier",
        "Feedforward Neural Network"
    ],
    "Test Accuracy": [
        0.9953,      
        test_acc
    ],
    "Macro F1": [
        0.9955,      
        test_f1
    ],
    "Training Time (s)": [
        0.4, 
        training_time      
    ],
    "Parameters / Trees": [
        100,     
        nn_params
    ]
})

print(comparison)

# %% [markdown]
# **Student Reasoning — Final evaluation**
# *1. Which obesity levels does the network still confuse, and are they the same ones your
# Lab 2 classifier confused?*
# *2. Who wins the showdown — the neural network or the classical model? Was the extra effort
# of deep learning worth it on THIS dataset? When would it be?*
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ---
# # Section 3 — Reflection
#
# *Answer in a few sentences each:*
#
# 1. **The black box, opened:** Name the three most important things happening inside
#    `loss.backward()` and `optimizer.step()`, in your own words.
# 2. **Hyperparameters:** If you could tune only ONE hyperparameter on a new problem, which
#    would you pick and why?
# 3. **Overfitting:** Across your experiments, where did you see the biggest
#    train-vs-validation gap, and which intervention reduced it most?
# 4. **Looking ahead:** This network treats every input feature independently. Next lab we move
#    to images, where nearby pixels are related. Why might a plain MLP struggle with images,
#    and what property should a better architecture have?
#
# > **Answer:** [Double-click to edit]

# %% [markdown]
# ---
# ### Submission checklist
#
# - [ ] All cells run top-to-bottom with no errors (`Kernel -> Restart & Run All`).
# - [ ] Every **Student Reasoning** box is filled in with full sentences.
# - [ ] Plots are visible in the saved notebook (loss curves, fits, experiments, confusion matrix).
# - [ ] Notebook committed and pushed to your `lab-3-feedforward-networks` repository, with
#       incremental commits (not one final dump).
# - [ ] Repository link submitted to the course portal.
# - [ ] AI Declaration form in Repository.
